# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
import os

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
country_code=[]


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        country_code.append(country)
        
#
       
#print the city count to confirm sufficient count
print(len(cities))
#create data frame to store this information. Columns with additional info can be appended later
weather_df=pd.DataFrame({"City": cities,"Country":country_code})
#created a csv to view list of cities 
weather_df.to_csv("test_cities.csv", index=False)
# Out:
# 637

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import openweathermapy.core as owm
from api_keys import api_key
import json


settings = {"units": "metric", "appid": api_key}
weather_data = []
#weather_df["Country"]=""
weather_df["Latitude"]=""
weather_df["Longitude"]=""
weather_df["DateTime"]=""
weather_df["CurrentTemp"]=""
weather_df["MaxTemp"]=""
weather_df["WindSpeed"]=""
weather_df["Cloudiness"]=""
weather_df["Humidity"]= ""




for index, row in weather_df.iterrows():
    #want the city name from my df
    city=row['City'].title()
    country=row['Country'].upper()
    time.sleep(1)

    
    #make API request and print processing message
    print(f"Retrieving record {index+1} of {len(cities)}: {city}, {country}.")
    try:
        weather_response=owm.get_current(city,**settings)
    
        #print(weather_response)
        print(f"The weather in {city} is {weather_response['main']['temp']}C with {weather_response['weather'][0]['description']}.")
        weather_df.loc[index,'City']=city
        weather_df.loc[index, 'Country']=weather_response['sys']['country'].upper()
        weather_df.loc[index, 'Latitude'] = weather_response['coord']['lat']
        weather_df.loc[index, 'Longitude'] = weather_response['coord']['lon']
        weather_df.loc[index, 'DateTime']= weather_response['dt']
        weather_df.loc[index, 'CurrentTemp'] = weather_response['main']['temp']
        weather_df.loc[index, 'MaxTemp']= weather_response['main']['temp_max']
        weather_df.loc[index, 'Humidity']=weather_response['main']['humidity']
        weather_df.loc[index, 'WindSpeed'] = weather_response['wind']['speed']
        weather_df.loc[index, 'Cloudiness']= weather_response['clouds']['all']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    
    except:
        print(f'* No weather data available for this city. ({city}, {country}) *') 
        
    print("------------")
# Out:
# Retrieving record 1 of 637: Mataura, PF.
# The weather in Mataura is 15.56C with clear sky.
# ------------
# Retrieving record 2 of 637: Cape Town, ZA.
# The weather in Cape Town is 19.39C with clear sky.
# ------------
# Retrieving record 3 of 637: Maine-Soroa, NE.
# The weather in Maine-Soroa is 23.91C with scattered clouds.
# ------------
# Retrieving record 4 of 637: Castro, CL.
# The weather in Castro is 12C with clear sky.
# ------------
# Retrieving record 5 of 637: Ostrogozhsk, RU.
# The weather in Ostrogozhsk is 0.16C with overcast clouds.
# ------------
# Retrieving record 6 of 637: Fare, PF.
# The weather in Fare is 28.11C with broken clouds.
# ------------
# Retrieving record 7 of 637: Albany, AU.
# The weather in Albany is 9.41C with few clouds.
# ------------
# Retrieving record 8 of 637: Pisco, PE.
# The weather in Pisco is 22C with broken clouds.
# ------------
# Retrieving record 9 of 637: Kapaa, US.
# The weather in Kapaa is 25.9C with few clouds.
# ------------
# Retrieving record 10 of 637: Busselton, AU.
# The weather in Busselton is 22C with few clouds.
# ------------
# Retrieving record 11 of 637: Fort Saint John, CA.
# * No weather data available for this city. (Fort Saint John, CA) *
# ------------
# Retrieving record 12 of 637: Jinchengjiang, CN.
# * No weather data available for this city. (Jinchengjiang, CN) *
# ------------
# Retrieving record 13 of 637: Lebu, CL.
# The weather in Lebu is 15C with few clouds.
# ------------
# Retrieving record 14 of 637: Derzhavinsk, KZ.
# The weather in Derzhavinsk is -11.25C with clear sky.
# ------------
# Retrieving record 15 of 637: Trairi, BR.
# The weather in Trairi is 27.31C with broken clouds.
# ------------
# Retrieving record 16 of 637: Norman Wells, CA.
# The weather in Norman Wells is -4C with clear sky.
# ------------
# Retrieving record 17 of 637: Barrow, US.
# The weather in Barrow is 17.81C with light rain.
# ------------
# Retrieving record 18 of 637: Kiri Buru, IN.
# The weather in Kiri Buru is 21.51C with clear sky.
# ------------
# Retrieving record 19 of 637: Birao, CF.
# The weather in Birao is 21.51C with scattered clouds.
# ------------
# Retrieving record 20 of 637: Ushuaia, AR.
# The weather in Ushuaia is 11C with scattered clouds.
# ------------
# Retrieving record 21 of 637: Amderma, RU.
# * No weather data available for this city. (Amderma, RU) *
# ------------
# Retrieving record 22 of 637: Bluff, NZ.
# The weather in Bluff is 20.76C with heavy intensity rain.
# ------------
# Retrieving record 23 of 637: Pontianak, ID.
# The weather in Pontianak is 25C with few clouds.
# ------------
# Retrieving record 24 of 637: Atbasar, KZ.
# The weather in Atbasar is -9.2C with clear sky.
# ------------
# Retrieving record 25 of 637: Arraial Do Cabo, BR.
# The weather in Arraial Do Cabo is 25C with broken clouds.
# ------------
# Retrieving record 26 of 637: Nizhneyansk, RU.
# * No weather data available for this city. (Nizhneyansk, RU) *
# ------------
# Retrieving record 27 of 637: Tuktoyaktuk, CA.
# The weather in Tuktoyaktuk is -15C with scattered clouds.
# ------------
# Retrieving record 28 of 637: Erenhot, CN.
# The weather in Erenhot is 8.06C with clear sky.
# ------------
# Retrieving record 29 of 637: Illoqqortoormiut, GL.
# * No weather data available for this city. (Illoqqortoormiut, GL) *
# ------------
# Retrieving record 30 of 637: Hithadhoo, MV.
# The weather in Hithadhoo is 28.86C with broken clouds.
# ------------
# Retrieving record 31 of 637: Vaini, TO.
# The weather in Vaini is 20C with clear sky.
# ------------
# Retrieving record 32 of 637: Antofagasta, CL.
# The weather in Antofagasta is 19C with few clouds.
# ------------
# Retrieving record 33 of 637: Coquimbo, CL.
# The weather in Coquimbo is 16C with broken clouds.
# ------------
# Retrieving record 34 of 637: Victoria, SC.
# The weather in Victoria is 27.41C with broken clouds.
# ------------
# Retrieving record 35 of 637: Morondava, MG.
# The weather in Morondava is 26.21C with scattered clouds.
# ------------
# Retrieving record 36 of 637: Pevek, RU.
# The weather in Pevek is -25.2C with clear sky.
# ------------
# Retrieving record 37 of 637: Te Anau, NZ.
# The weather in Te Anau is 18.41C with clear sky.
# ------------
# Retrieving record 38 of 637: Carnarvon, AU.
# The weather in Carnarvon is 15.56C with light rain.
# ------------
# Retrieving record 39 of 637: Bengkulu, ID.
# * No weather data available for this city. (Bengkulu, ID) *
# ------------
# Retrieving record 40 of 637: Georgetown, SH.
# The weather in Georgetown is 25.93C with scattered clouds.
# ------------
# Retrieving record 41 of 637: Peniche, PT.
# The weather in Peniche is 10.13C with mist.
# ------------
# Retrieving record 42 of 637: Rikitea, PF.
# The weather in Rikitea is 25.51C with broken clouds.
# ------------
# Retrieving record 43 of 637: Fort Nelson, CA.
# The weather in Fort Nelson is 6C with broken clouds.
# ------------
# Retrieving record 44 of 637: Cidreira, BR.
# The weather in Cidreira is 22.26C with scattered clouds.
# ------------
# Retrieving record 45 of 637: Puerto Rondon, CO.
# The weather in Puerto Rondon is 24.26C with few clouds.
# ------------
# Retrieving record 46 of 637: Ribeira Grande, PT.
# The weather in Ribeira Grande is 16.46C with overcast clouds.
# ------------
# Retrieving record 47 of 637: Tiksi, RU.
# The weather in Tiksi is -25.65C with clear sky.
# ------------
# Retrieving record 48 of 637: Hobart, AU.
# The weather in Hobart is 21.22C with broken clouds.
# ------------
# Retrieving record 49 of 637: Pamplona, ES.
# The weather in Pamplona is 5.39C with clear sky.
# ------------
# Retrieving record 50 of 637: Upernavik, GL.
# The weather in Upernavik is -21.69C with few clouds.
# ------------
# Retrieving record 51 of 637: Bathsheba, BB.
# The weather in Bathsheba is 26C with few clouds.
# ------------
# Retrieving record 52 of 637: Chokurdakh, RU.
# The weather in Chokurdakh is -24.75C with broken clouds.
# ------------
# Retrieving record 53 of 637: Bredasdorp, ZA.
# The weather in Bredasdorp is 21.72C with light rain.
# ------------
# Retrieving record 54 of 637: Katsuura, JP.
# The weather in Katsuura is 8.6C with scattered clouds.
# ------------
# Retrieving record 55 of 637: Rantepao, ID.
# The weather in Rantepao is 25.81C with few clouds.
# ------------
# Retrieving record 56 of 637: Pokhara, NP.
# The weather in Pokhara is 13.61C with clear sky.
# ------------
# Retrieving record 57 of 637: Agirish, RU.
# The weather in Agirish is -8C with broken clouds.
# ------------
# Retrieving record 58 of 637: Sergeyevka, KZ.
# The weather in Sergeyevka is -7.6C with clear sky.
# ------------
# Retrieving record 59 of 637: Cockburn Town, TC.
# The weather in Cockburn Town is 23.61C with light rain.
# ------------
# Retrieving record 60 of 637: Nhulunbuy, AU.
# The weather in Nhulunbuy is 31C with broken clouds.
# ------------
# Retrieving record 61 of 637: Bonavista, CA.
# The weather in Bonavista is -0.57C with overcast clouds.
# ------------
# Retrieving record 62 of 637: Haines Junction, CA.
# The weather in Haines Junction is -4.75C with scattered clouds.
# ------------
# Retrieving record 63 of 637: Gao, ML.
# The weather in Gao is 20.86C with clear sky.
# ------------
# Retrieving record 64 of 637: Kohlu, PK.
# The weather in Kohlu is 9.91C with overcast clouds.
# ------------
# Retrieving record 65 of 637: Tumannyy, RU.
# * No weather data available for this city. (Tumannyy, RU) *
# ------------
# Retrieving record 66 of 637: Kaeo, NZ.
# The weather in Kaeo is 26.11C with few clouds.
# ------------
# Retrieving record 67 of 637: College, US.
# The weather in College is 5.33C with broken clouds.
# ------------
# Retrieving record 68 of 637: Punta Arenas, CL.
# The weather in Punta Arenas is 8.94C with scattered clouds.
# ------------
# Retrieving record 69 of 637: Sao Joao Da Barra, BR.
# The weather in Sao Joao Da Barra is 26.96C with light rain.
# ------------
# Retrieving record 70 of 637: San Cristobal, EC.
# The weather in San Cristobal is 11.57C with scattered clouds.
# ------------
# Retrieving record 71 of 637: Taolanaro, MG.
# * No weather data available for this city. (Taolanaro, MG) *
# ------------
# Retrieving record 72 of 637: Nemuro, JP.
# The weather in Nemuro is 0C with broken clouds.
# ------------
# Retrieving record 73 of 637: Karakendzha, TJ.
# * No weather data available for this city. (Karakendzha, TJ) *
# ------------
# Retrieving record 74 of 637: Alyangula, AU.
# The weather in Alyangula is 31C with broken clouds.
# ------------
# Retrieving record 75 of 637: Butaritari, KI.
# The weather in Butaritari is 26.66C with moderate rain.
# ------------
# Retrieving record 76 of 637: Puerto Ayora, EC.
# The weather in Puerto Ayora is 25.19C with clear sky.
# ------------
# Retrieving record 77 of 637: Bethel, US.
# The weather in Bethel is -0.75C with clear sky.
# ------------
# Retrieving record 78 of 637: Henties Bay, NA.
# The weather in Henties Bay is 16.67C with overcast clouds.
# ------------
# Retrieving record 79 of 637: Ust-Tsilma, RU.
# The weather in Ust-Tsilma is -10.25C with scattered clouds.
# ------------
# Retrieving record 80 of 637: Dikson, RU.
# The weather in Dikson is -17.77C with clear sky.
# ------------
# Retrieving record 81 of 637: Barentsburg, SJ.
# * No weather data available for this city. (Barentsburg, SJ) *
# ------------
# Retrieving record 82 of 637: Maryborough, AU.
# The weather in Maryborough is 23.31C with light rain.
# ------------
# Retrieving record 83 of 637: Attawapiskat, CA.
# * No weather data available for this city. (Attawapiskat, CA) *
# ------------
# Retrieving record 84 of 637: Mocuba, MZ.
# The weather in Mocuba is 21.96C with scattered clouds.
# ------------
# Retrieving record 85 of 637: Aquiraz, BR.
# The weather in Aquiraz is 23.61C with thunderstorm.
# ------------
# Retrieving record 86 of 637: Hilo, US.
# The weather in Hilo is 22.81C with clear sky.
# ------------
# Retrieving record 87 of 637: Hobyo, SO.
# The weather in Hobyo is 26.26C with broken clouds.
# ------------
# Retrieving record 88 of 637: Portree, GB.
# The weather in Portree is 2.78C with light rain.
# ------------
# Retrieving record 89 of 637: Korla, CN.
# * No weather data available for this city. (Korla, CN) *
# ------------
# Retrieving record 90 of 637: Mamou, GN.
# The weather in Mamou is 18.76C with clear sky.
# ------------
# Retrieving record 91 of 637: Mahebourg, MU.
# The weather in Mahebourg is 23.78C with few clouds.
# ------------
# Retrieving record 92 of 637: Saleaula, WS.
# * No weather data available for this city. (Saleaula, WS) *
# ------------
# Retrieving record 93 of 637: Severo-Kurilsk, RU.
# The weather in Severo-Kurilsk is -2.35C with overcast clouds.
# ------------
# Retrieving record 94 of 637: Torbay, CA.
# The weather in Torbay is -0.98C with broken clouds.
# ------------
# Retrieving record 95 of 637: Mount Isa, AU.
# The weather in Mount Isa is 33C with clear sky.
# ------------
# Retrieving record 96 of 637: Tabiauea, KI.
# * No weather data available for this city. (Tabiauea, KI) *
# ------------
# Retrieving record 97 of 637: Avarua, CK.
# The weather in Avarua is 25C with light rain.
# ------------
# Retrieving record 98 of 637: Clyde River, CA.
# The weather in Clyde River is -32C with clear sky.
# ------------
# Retrieving record 99 of 637: Grindavik, IS.
# The weather in Grindavik is 1.44C with light snow.
# ------------
# Retrieving record 100 of 637: Osa, RU.
# The weather in Osa is -10.7C with scattered clouds.
# ------------
# Retrieving record 101 of 637: Cacoal, BR.
# The weather in Cacoal is 23.31C with clear sky.
# ------------
# Retrieving record 102 of 637: Atuona, PF.
# The weather in Atuona is 28.01C with few clouds.
# ------------
# Retrieving record 103 of 637: Leh, IN.
# The weather in Leh is -21.3C with scattered clouds.
# ------------
# Retrieving record 104 of 637: Ponta Do Sol, CV.
# The weather in Ponta Do Sol is 19.46C with light rain.
# ------------
# Retrieving record 105 of 637: Sri Aman, MY.
# The weather in Sri Aman is 27C with broken clouds.
# ------------
# Retrieving record 106 of 637: Yellowknife, CA.
# The weather in Yellowknife is -5.32C with light snow.
# ------------
# Retrieving record 107 of 637: Yokadouma, CM.
# The weather in Yokadouma is 22.36C with overcast clouds.
# ------------
# Retrieving record 108 of 637: Zhangye, CN.
# The weather in Zhangye is 4.96C with clear sky.
# ------------
# Retrieving record 109 of 637: Axim, GH.
# The weather in Axim is 28.26C with few clouds.
# ------------
# Retrieving record 110 of 637: Sampit, ID.
# The weather in Sampit is 28.61C with light rain.
# ------------
# Retrieving record 111 of 637: Camacupa, AO.
# The weather in Camacupa is 16.76C with moderate rain.
# ------------
# Retrieving record 112 of 637: Grand River South East, MU.
# * No weather data available for this city. (Grand River South East, MU) *
# ------------
# Retrieving record 113 of 637: Ursulo Galvan, MX.
# The weather in Ursulo Galvan is 16C with light intensity drizzle.
# ------------
# Retrieving record 114 of 637: Umzimvubu, ZA.
# * No weather data available for this city. (Umzimvubu, ZA) *
# ------------
# Retrieving record 115 of 637: Codrington, AG.
# The weather in Codrington is 22.31C with overcast clouds.
# ------------
# Retrieving record 116 of 637: Bergen, NL.
# * No weather data available for this city. (Bergen, NL) *
# ------------
# Retrieving record 117 of 637: Jamestown, SH.
# The weather in Jamestown is 22.01C with clear sky.
# ------------
# Retrieving record 118 of 637: Yar-Sale, RU.
# The weather in Yar-Sale is -12.2C with broken clouds.
# ------------
# Retrieving record 119 of 637: Dzhusaly, KZ.
# * No weather data available for this city. (Dzhusaly, KZ) *
# ------------
# Retrieving record 120 of 637: Port Alfred, ZA.
# The weather in Port Alfred is 22.23C with light rain.
# ------------
# Retrieving record 121 of 637: Kavieng, PG.
# The weather in Kavieng is 28.86C with broken clouds.
# ------------
# Retrieving record 122 of 637: Caidian, CN.
# The weather in Caidian is 14C with broken clouds.
# ------------
# Retrieving record 123 of 637: Faya, TD.
# The weather in Faya is 14.51C with clear sky.
# ------------
# Retrieving record 124 of 637: Half Moon Bay, US.
# The weather in Half Moon Bay is 16.48C with haze.
# ------------
# Retrieving record 125 of 637: Iqaluit, CA.
# The weather in Iqaluit is -15C with broken clouds.
# ------------
# Retrieving record 126 of 637: Rio Grande, BR.
# The weather in Rio Grande is 22.16C with clear sky.
# ------------
# Retrieving record 127 of 637: Wanning, CN.
# The weather in Wanning is 9.19C with broken clouds.
# ------------
# Retrieving record 128 of 637: Nome, US.
# The weather in Nome is 13.89C with light rain.
# ------------
# Retrieving record 129 of 637: Vila, VU.
# The weather in Vila is 10.64C with clear sky.
# ------------
# Retrieving record 130 of 637: East London, ZA.
# The weather in East London is 24.46C with broken clouds.
# ------------
# Retrieving record 131 of 637: Sitka, US.
# The weather in Sitka is 6.11C with clear sky.
# ------------
# Retrieving record 132 of 637: Narsaq, GL.
# The weather in Narsaq is -9C with few clouds.
# ------------
# Retrieving record 133 of 637: Carutapera, BR.
# The weather in Carutapera is 26.26C with broken clouds.
# ------------
# Retrieving record 134 of 637: Zyryanka, RU.
# The weather in Zyryanka is -20.9C with scattered clouds.
# ------------
# Retrieving record 135 of 637: Qaanaaq, GL.
# The weather in Qaanaaq is -29C with few clouds.
# ------------
# Retrieving record 136 of 637: Moyo, UG.
# * No weather data available for this city. (Moyo, UG) *
# ------------
# Retrieving record 137 of 637: Ilulissat, GL.
# The weather in Ilulissat is -16C with broken clouds.
# ------------
# Retrieving record 138 of 637: Las Choapas, MX.
# The weather in Las Choapas is 24C with scattered clouds.
# ------------
# Retrieving record 139 of 637: Lavrentiya, RU.
# The weather in Lavrentiya is -8.7C with broken clouds.
# ------------
# Retrieving record 140 of 637: Guerrero Negro, MX.
# The weather in Guerrero Negro is 16.76C with few clouds.
# ------------
# Retrieving record 141 of 637: Ratangarh, IN.
# The weather in Ratangarh is 16.16C with clear sky.
# ------------
# Retrieving record 142 of 637: Griffith, AU.
# The weather in Griffith is 27.07C with clear sky.
# ------------
# Retrieving record 143 of 637: Ostrovnoy, RU.
# The weather in Ostrovnoy is -4.25C with broken clouds.
# ------------
# Retrieving record 144 of 637: Longyearbyen, SJ.
# The weather in Longyearbyen is -18C with few clouds.
# ------------
# Retrieving record 145 of 637: Diego De Almagro, CL.
# The weather in Diego De Almagro is 13.91C with clear sky.
# ------------
# Retrieving record 146 of 637: Arlit, NE.
# The weather in Arlit is 17.36C with clear sky.
# ------------
# Retrieving record 147 of 637: Turukhansk, RU.
# The weather in Turukhansk is -20.3C with clear sky.
# ------------
# Retrieving record 148 of 637: Grand Gaube, MU.
# The weather in Grand Gaube is 23.4C with few clouds.
# ------------
# Retrieving record 149 of 637: Bambous Virieux, MU.
# The weather in Bambous Virieux is 23.67C with few clouds.
# ------------
# Retrieving record 150 of 637: Galiwinku, AU.
# * No weather data available for this city. (Galiwinku, AU) *
# ------------
# Retrieving record 151 of 637: Paamiut, GL.
# The weather in Paamiut is -5.65C with few clouds.
# ------------
# Retrieving record 152 of 637: Tuggurt, DZ.
# * No weather data available for this city. (Tuggurt, DZ) *
# ------------
# Retrieving record 153 of 637: Cabo San Lucas, MX.
# The weather in Cabo San Lucas is 19.45C with broken clouds.
# ------------
# Retrieving record 154 of 637: Roebourne, AU.
# The weather in Roebourne is 40.66C with clear sky.
# ------------
# Retrieving record 155 of 637: Nuevitas, CU.
# The weather in Nuevitas is 23C with clear sky.
# ------------
# Retrieving record 156 of 637: Lasa, CN.
# The weather in Lasa is 13.17C with light intensity shower rain.
# ------------
# Retrieving record 157 of 637: Padang, ID.
# The weather in Padang is 28.16C with clear sky.
# ------------
# Retrieving record 158 of 637: Vanino, RU.
# The weather in Vanino is -2.78C with overcast clouds.
# ------------
# Retrieving record 159 of 637: Cherskiy, RU.
# The weather in Cherskiy is -27.77C with scattered clouds.
# ------------
# Retrieving record 160 of 637: Touros, BR.
# The weather in Touros is 25C with broken clouds.
# ------------
# Retrieving record 161 of 637: Lagoa, PT.
# The weather in Lagoa is 12.46C with clear sky.
# ------------
# Retrieving record 162 of 637: Bandeirantes, BR.
# The weather in Bandeirantes is 22.11C with light rain.
# ------------
# Retrieving record 163 of 637: Kruisfontein, ZA.
# The weather in Kruisfontein is 20.01C with overcast clouds.
# ------------
# Retrieving record 164 of 637: Pacific Grove, US.
# The weather in Pacific Grove is 15.75C with clear sky.
# ------------
# Retrieving record 165 of 637: Provideniya, RU.
# The weather in Provideniya is -7.9C with clear sky.
# ------------
# Retrieving record 166 of 637: Broken Hill, AU.
# The weather in Broken Hill is 26C with clear sky.
# ------------
# Retrieving record 167 of 637: Leningradskiy, RU.
# The weather in Leningradskiy is -23C with broken clouds.
# ------------
# Retrieving record 168 of 637: Hermanus, ZA.
# The weather in Hermanus is 21.31C with clear sky.
# ------------
# Retrieving record 169 of 637: Saint Anthony, CA.
# The weather in Saint Anthony is -0.03C with clear sky.
# ------------
# Retrieving record 170 of 637: Sisophon, KH.
# The weather in Sisophon is 28.96C with few clouds.
# ------------
# Retrieving record 171 of 637: Belyy Yar, RU.
# The weather in Belyy Yar is -5C with clear sky.
# ------------
# Retrieving record 172 of 637: Sarkand, KZ.
# The weather in Sarkand is 3.96C with light rain.
# ------------
# Retrieving record 173 of 637: Siguiri, GN.
# The weather in Siguiri is 22.36C with clear sky.
# ------------
# Retrieving record 174 of 637: Ancud, CL.
# The weather in Ancud is 12C with clear sky.
# ------------
# Retrieving record 175 of 637: Deputatskiy, RU.
# The weather in Deputatskiy is -21.65C with clear sky.
# ------------
# Retrieving record 176 of 637: Bull Savanna, JM.
# The weather in Bull Savanna is 20.61C with clear sky.
# ------------
# Retrieving record 177 of 637: Nikolskoye, RU.
# The weather in Nikolskoye is 2.03C with overcast clouds.
# ------------
# Retrieving record 178 of 637: Berbera, SO.
# * No weather data available for this city. (Berbera, SO) *
# ------------
# Retrieving record 179 of 637: Geraldton, AU.
# The weather in Geraldton is -10C with light snow.
# ------------
# Retrieving record 180 of 637: Bochalema, CO.
# The weather in Bochalema is 28C with haze.
# ------------
# Retrieving record 181 of 637: Beira, MZ.
# The weather in Beira is 3.53C with fog.
# ------------
# Retrieving record 182 of 637: Kodiak, US.
# The weather in Kodiak is 3.42C with clear sky.
# ------------
# Retrieving record 183 of 637: Zhigansk, RU.
# The weather in Zhigansk is -17.5C with few clouds.
# ------------
# Retrieving record 184 of 637: Cam Pha, VN.
# * No weather data available for this city. (Cam Pha, VN) *
# ------------
# Retrieving record 185 of 637: Kloulklubed, PW.
# The weather in Kloulklubed is 29C with broken clouds.
# ------------
# Retrieving record 186 of 637: Tsihombe, MG.
# * No weather data available for this city. (Tsihombe, MG) *
# ------------
# Retrieving record 187 of 637: Terra Nova, BR.
# The weather in Terra Nova is 29C with few clouds.
# ------------
# Retrieving record 188 of 637: Alta Floresta, BR.
# The weather in Alta Floresta is 25.61C with scattered clouds.
# ------------
# Retrieving record 189 of 637: Strai, NO.
# * No weather data available for this city. (Strai, NO) *
# ------------
# Retrieving record 190 of 637: Vila Velha, BR.
# The weather in Vila Velha is 23.64C with thunderstorm.
# ------------
# Retrieving record 191 of 637: Imbituba, BR.
# The weather in Imbituba is 24C with broken clouds.
# ------------
# Retrieving record 192 of 637: Saint-Francois, GP.
# The weather in Saint-Francois is 9.66C with overcast clouds.
# ------------
# Retrieving record 193 of 637: Souris, CA.
# The weather in Souris is 4.92C with overcast clouds.
# ------------
# Retrieving record 194 of 637: Ossora, RU.
# The weather in Ossora is -12.9C with few clouds.
# ------------
# Retrieving record 195 of 637: Esil, KZ.
# The weather in Esil is -10.9C with clear sky.
# ------------
# Retrieving record 196 of 637: Hofn, IS.
# The weather in Hofn is 3.01C with light rain.
# ------------
# Retrieving record 197 of 637: Khor, QA.
# The weather in Khor is 2.46C with clear sky.
# ------------
# Retrieving record 198 of 637: Jiuquan, CN.
# The weather in Jiuquan is -0.3C with clear sky.
# ------------
# Retrieving record 199 of 637: Esperance, AU.
# The weather in Esperance is 25.12C with few clouds.
# ------------
# Retrieving record 200 of 637: Santa Rosalia, MX.
# The weather in Santa Rosalia is 10.08C with clear sky.
# ------------
# Retrieving record 201 of 637: Marienburg, SR.
# The weather in Marienburg is 6.78C with broken clouds.
# ------------
# Retrieving record 202 of 637: Kununurra, AU.
# The weather in Kununurra is 31C with clear sky.
# ------------
# Retrieving record 203 of 637: Mar Del Plata, AR.
# The weather in Mar Del Plata is 13.11C with clear sky.
# ------------
# Retrieving record 204 of 637: Yenagoa, NG.
# The weather in Yenagoa is 24.86C with few clouds.
# ------------
# Retrieving record 205 of 637: Aklavik, CA.
# The weather in Aklavik is -9C with few clouds.
# ------------
# Retrieving record 206 of 637: Doctor Arroyo, MX.
# The weather in Doctor Arroyo is 11.36C with light rain.
# ------------
# Retrieving record 207 of 637: Greenwood, US.
# The weather in Greenwood is 9.73C with scattered clouds.
# ------------
# Retrieving record 208 of 637: Patuli, IN.
# The weather in Patuli is 23.26C with clear sky.
# ------------
# Retrieving record 209 of 637: Port Elizabeth, ZA.
# The weather in Port Elizabeth is 13.75C with light rain.
# ------------
# Retrieving record 210 of 637: Savinka, RU.
# The weather in Savinka is -2.85C with broken clouds.
# ------------
# Retrieving record 211 of 637: Cabedelo, BR.
# The weather in Cabedelo is 25C with clear sky.
# ------------
# Retrieving record 212 of 637: Ettaiyapuram, IN.
# The weather in Ettaiyapuram is 26C with haze.
# ------------
# Retrieving record 213 of 637: Lovozero, RU.
# The weather in Lovozero is -3.2C with overcast clouds.
# ------------
# Retrieving record 214 of 637: Princeton, CA.
# The weather in Princeton is 1.99C with scattered clouds.
# ------------
# Retrieving record 215 of 637: Tura, RU.
# The weather in Tura is 21.76C with few clouds.
# ------------
# Retrieving record 216 of 637: Morant Bay, JM.
# The weather in Morant Bay is 27C with few clouds.
# ------------
# Retrieving record 217 of 637: Nichinan, JP.
# The weather in Nichinan is 10.61C with few clouds.
# ------------
# Retrieving record 218 of 637: Kichera, RU.
# The weather in Kichera is -5C with overcast clouds.
# ------------
# Retrieving record 219 of 637: Cheney, US.
# The weather in Cheney is 4.92C with broken clouds.
# ------------
# Retrieving record 220 of 637: Kozmodemyansk, RU.
# The weather in Kozmodemyansk is -7C with clear sky.
# ------------
# Retrieving record 221 of 637: Igbo Ora, NG.
# The weather in Igbo Ora is 26.11C with clear sky.
# ------------
# Retrieving record 222 of 637: Lalibela, ET.
# The weather in Lalibela is 9.16C with scattered clouds.
# ------------
# Retrieving record 223 of 637: Chulakivka, UA.
# The weather in Chulakivka is 2.31C with few clouds.
# ------------
# Retrieving record 224 of 637: Christchurch, NZ.
# The weather in Christchurch is 17.93C with scattered clouds.
# ------------
# Retrieving record 225 of 637: Andoain, ES.
# The weather in Andoain is 4.42C with clear sky.
# ------------
# Retrieving record 226 of 637: Berlevag, NO.
# The weather in Berlevag is -2C with broken clouds.
# ------------
# Retrieving record 227 of 637: Guaranda, EC.
# The weather in Guaranda is 17.96C with heavy intensity rain.
# ------------
# Retrieving record 228 of 637: Port Hueneme, US.
# The weather in Port Hueneme is 18.71C with few clouds.
# ------------
# Retrieving record 229 of 637: Saskylakh, RU.
# The weather in Saskylakh is -17.55C with overcast clouds.
# ------------
# Retrieving record 230 of 637: Lompoc, US.
# The weather in Lompoc is 16.07C with clear sky.
# ------------
# Retrieving record 231 of 637: Ruatoria, NZ.
# * No weather data available for this city. (Ruatoria, NZ) *
# ------------
# Retrieving record 232 of 637: Araouane, ML.
# The weather in Araouane is 13.66C with clear sky.
# ------------
# Retrieving record 233 of 637: Hunza, PK.
# * No weather data available for this city. (Hunza, PK) *
# ------------
# Retrieving record 234 of 637: San Policarpo, PH.
# The weather in San Policarpo is 27.51C with broken clouds.
# ------------
# Retrieving record 235 of 637: Acajutla, SV.
# The weather in Acajutla is 24.11C with few clouds.
# ------------
# Retrieving record 236 of 637: Praia Da Vitoria, PT.
# The weather in Praia Da Vitoria is 15C with few clouds.
# ------------
# Retrieving record 237 of 637: Poum, NC.
# The weather in Poum is -7.85C with clear sky.
# ------------
# Retrieving record 238 of 637: Saldanha, ZA.
# The weather in Saldanha is -0.85C with clear sky.
# ------------
# Retrieving record 239 of 637: Kedrovyy, RU.
# The weather in Kedrovyy is -4C with clear sky.
# ------------
# Retrieving record 240 of 637: Olafsvik, IS.
# * No weather data available for this city. (Olafsvik, IS) *
# ------------
# Retrieving record 241 of 637: Champerico, GT.
# The weather in Champerico is 27C with broken clouds.
# ------------
# Retrieving record 242 of 637: Hirson, FR.
# The weather in Hirson is 9.28C with light rain.
# ------------
# Retrieving record 243 of 637: Flinders, AU.
# The weather in Flinders is 23.28C with scattered clouds.
# ------------
# Retrieving record 244 of 637: Tahe, CN.
# The weather in Tahe is 0.91C with clear sky.
# ------------
# Retrieving record 245 of 637: Varhaug, NO.
# The weather in Varhaug is 4.26C with broken clouds.
# ------------
# Retrieving record 246 of 637: Manturovo, RU.
# The weather in Manturovo is -6.35C with broken clouds.
# ------------
# Retrieving record 247 of 637: Luderitz, NA.
# The weather in Luderitz is 15.41C with broken clouds.
# ------------
# Retrieving record 248 of 637: Kathu, TH.
# The weather in Kathu is 22.22C with broken clouds.
# ------------
# Retrieving record 249 of 637: Yulara, AU.
# The weather in Yulara is 31C with scattered clouds.
# ------------
# Retrieving record 250 of 637: Hambantota, LK.
# The weather in Hambantota is 24C with clear sky.
# ------------
# Retrieving record 251 of 637: Port Macquarie, AU.
# The weather in Port Macquarie is 21.37C with broken clouds.
# ------------
# Retrieving record 252 of 637: Dingle, IE.
# The weather in Dingle is 30.61C with clear sky.
# ------------
# Retrieving record 253 of 637: Ellisras, ZA.
# The weather in Ellisras is 17.51C with clear sky.
# ------------
# Retrieving record 254 of 637: Sentyabrskiy, RU.
# * No weather data available for this city. (Sentyabrskiy, RU) *
# ------------
# Retrieving record 255 of 637: Kamenskoye, RU.
# * No weather data available for this city. (Kamenskoye, RU) *
# ------------
# Retrieving record 256 of 637: Baykit, RU.
# The weather in Baykit is -3.55C with clear sky.
# ------------
# Retrieving record 257 of 637: Mabaruma, GY.
# The weather in Mabaruma is 25.16C with overcast clouds.
# ------------
# Retrieving record 258 of 637: Novoagansk, RU.
# The weather in Novoagansk is -2.75C with broken clouds.
# ------------
# Retrieving record 259 of 637: Ostrov, RU.
# The weather in Ostrov is 2C with light rain.
# ------------
# Retrieving record 260 of 637: Souillac, MU.
# The weather in Souillac is 9.57C with light intensity drizzle rain.
# ------------
# Retrieving record 261 of 637: Markova, RU.
# The weather in Markova is -0.96C with clear sky.
# ------------
# Retrieving record 262 of 637: Maraba, BR.
# The weather in Maraba is 27C with clear sky.
# ------------
# Retrieving record 263 of 637: Vuktyl, RU.
# The weather in Vuktyl is -17.15C with clear sky.
# ------------
# Retrieving record 264 of 637: Calabozo, VE.
# The weather in Calabozo is 29.16C with scattered clouds.
# ------------
# Retrieving record 265 of 637: Hailar, CN.
# The weather in Hailar is 1.61C with clear sky.
# ------------
# Retrieving record 266 of 637: Yasnyy, RU.
# The weather in Yasnyy is -1.35C with overcast clouds.
# ------------
# Retrieving record 267 of 637: Belushya Guba, RU.
# * No weather data available for this city. (Belushya Guba, RU) *
# ------------
# Retrieving record 268 of 637: Nanortalik, GL.
# The weather in Nanortalik is -5.15C with scattered clouds.
# ------------
# Retrieving record 269 of 637: Beringovskiy, RU.
# The weather in Beringovskiy is -15.8C with broken clouds.
# ------------
# Retrieving record 270 of 637: Hay River, CA.
# The weather in Hay River is 1C with broken clouds.
# ------------
# Retrieving record 271 of 637: Labuhan, ID.
# The weather in Labuhan is 25.86C with light rain.
# ------------
# Retrieving record 272 of 637: Elbistan, TR.
# The weather in Elbistan is 1.01C with broken clouds.
# ------------
# Retrieving record 273 of 637: Lahaina, US.
# The weather in Lahaina is 23.9C with few clouds.
# ------------
# Retrieving record 274 of 637: Airai, PW.
# The weather in Airai is 27.51C with broken clouds.
# ------------
# Retrieving record 275 of 637: Saint George, BM.
# The weather in Saint George is 7.22C with clear sky.
# ------------
# Retrieving record 276 of 637: Avera, PF.
# The weather in Avera is 16.78C with clear sky.
# ------------
# Retrieving record 277 of 637: Rawson, AR.
# The weather in Rawson is 16.51C with light rain.
# ------------
# Retrieving record 278 of 637: Quepos, CR.
# The weather in Quepos is 20.59C with few clouds.
# ------------
# Retrieving record 279 of 637: Muros, ES.
# The weather in Muros is 6.1C with few clouds.
# ------------
# Retrieving record 280 of 637: Hihya, EG.
# The weather in Hihya is 15.77C with scattered clouds.
# ------------
# Retrieving record 281 of 637: Isangel, VU.
# The weather in Isangel is 31C with broken clouds.
# ------------
# Retrieving record 282 of 637: Seoul, KR.
# The weather in Seoul is 2.98C with mist.
# ------------
# Retrieving record 283 of 637: Samarai, PG.
# The weather in Samarai is 24.51C with moderate rain.
# ------------
# Retrieving record 284 of 637: Chuy, UY.
# The weather in Chuy is 20.46C with clear sky.
# ------------
# Retrieving record 285 of 637: Gavle, SE.
# The weather in Gavle is 0C with overcast clouds.
# ------------
# Retrieving record 286 of 637: Saint-Philippe, RE.
# The weather in Saint-Philippe is 5C with light intensity shower rain.
# ------------
# Retrieving record 287 of 637: New Norfolk, AU.
# The weather in New Norfolk is 21.22C with broken clouds.
# ------------
# Retrieving record 288 of 637: La Romana, DO.
# The weather in La Romana is 24.16C with scattered clouds.
# ------------
# Retrieving record 289 of 637: Taoudenni, ML.
# The weather in Taoudenni is 16.01C with clear sky.
# ------------
# Retrieving record 290 of 637: Honiara, SB.
# The weather in Honiara is 27.01C with moderate rain.
# ------------
# Retrieving record 291 of 637: Muravlenko, RU.
# The weather in Muravlenko is -11.35C with overcast clouds.
# ------------
# Retrieving record 292 of 637: Karaul, RU.
# * No weather data available for this city. (Karaul, RU) *
# ------------
# Retrieving record 293 of 637: Almeirim, BR.
# The weather in Almeirim is 8.9C with clear sky.
# ------------
# Retrieving record 294 of 637: Karratha, AU.
# The weather in Karratha is 40.66C with clear sky.
# ------------
# Retrieving record 295 of 637: Westpunt, AN.
# * No weather data available for this city. (Westpunt, AN) *
# ------------
# Retrieving record 296 of 637: Ocos, GT.
# The weather in Ocos is 29C with scattered clouds.
# ------------
# Retrieving record 297 of 637: Umm Lajj, SA.
# The weather in Umm Lajj is 13.36C with clear sky.
# ------------
# Retrieving record 298 of 637: Barcelona, VE.
# The weather in Barcelona is 8.27C with broken clouds.
# ------------
# Retrieving record 299 of 637: Kieta, PG.
# The weather in Kieta is 24.26C with moderate rain.
# ------------
# Retrieving record 300 of 637: Launceston, AU.
# The weather in Launceston is 21.21C with broken clouds.
# ------------
# Retrieving record 301 of 637: Aginskoye, RU.
# The weather in Aginskoye is -0.57C with clear sky.
# ------------
# Retrieving record 302 of 637: Margate, ZA.
# The weather in Margate is 21.23C with broken clouds.
# ------------
# Retrieving record 303 of 637: Victor Harbor, AU.
# The weather in Victor Harbor is 26.16C with clear sky.
# ------------
# Retrieving record 304 of 637: Burica, PA.
# * No weather data available for this city. (Burica, PA) *
# ------------
# Retrieving record 305 of 637: Melbu, NO.
# The weather in Melbu is -3.35C with scattered clouds.
# ------------
# Retrieving record 306 of 637: Talcahuano, CL.
# The weather in Talcahuano is 16C with clear sky.
# ------------
# Retrieving record 307 of 637: Kisangani, CD.
# The weather in Kisangani is 20.71C with light rain.
# ------------
# Retrieving record 308 of 637: Thompson, CA.
# The weather in Thompson is -10C with few clouds.
# ------------
# Retrieving record 309 of 637: Svetlogorsk, RU.
# The weather in Svetlogorsk is -12C with clear sky.
# ------------
# Retrieving record 310 of 637: Bataipora, BR.
# The weather in Bataipora is 22.91C with few clouds.
# ------------
# Retrieving record 311 of 637: Presidencia Roque Saenz Pena, AR.
# The weather in Presidencia Roque Saenz Pena is 21.11C with moderate rain.
# ------------
# Retrieving record 312 of 637: Roald, NO.
# The weather in Roald is -2.64C with broken clouds.
# ------------
# Retrieving record 313 of 637: Cachira, CO.
# The weather in Cachira is 24.93C with haze.
# ------------
# Retrieving record 314 of 637: Sechura, PE.
# The weather in Sechura is 25.01C with few clouds.
# ------------
# Retrieving record 315 of 637: Coihaique, CL.
# The weather in Coihaique is 11C with clear sky.
# ------------
# Retrieving record 316 of 637: Tasiilaq, GL.
# The weather in Tasiilaq is -8C with clear sky.
# ------------
# Retrieving record 317 of 637: Butembo, CD.
# The weather in Butembo is 13.16C with clear sky.
# ------------
# Retrieving record 318 of 637: Vestmannaeyjar, IS.
# The weather in Vestmannaeyjar is 1.56C with light rain.
# ------------
# Retrieving record 319 of 637: San Jeronimo, MX.
# The weather in San Jeronimo is 8.86C with scattered clouds.
# ------------
# Retrieving record 320 of 637: Shingu, JP.
# The weather in Shingu is 8C with broken clouds.
# ------------
# Retrieving record 321 of 637: Maumere, ID.
# The weather in Maumere is 27.51C with broken clouds.
# ------------
# Retrieving record 322 of 637: Raver, IN.
# The weather in Raver is 21.16C with clear sky.
# ------------
# Retrieving record 323 of 637: Biltine, TD.
# The weather in Biltine is 22.11C with clear sky.
# ------------
# Retrieving record 324 of 637: Mpanda, TZ.
# The weather in Mpanda is 20.11C with few clouds.
# ------------
# Retrieving record 325 of 637: Harrismith, ZA.
# The weather in Harrismith is 10.26C with clear sky.
# ------------
# Retrieving record 326 of 637: Potchefstroom, ZA.
# The weather in Potchefstroom is 13.56C with clear sky.
# ------------
# Retrieving record 327 of 637: Port Hardy, CA.
# The weather in Port Hardy is 9C with overcast clouds.
# ------------
# Retrieving record 328 of 637: Onega, RU.
# The weather in Onega is -0.15C with broken clouds.
# ------------
# Retrieving record 329 of 637: Ahipara, NZ.
# The weather in Ahipara is 24.66C with broken clouds.
# ------------
# Retrieving record 330 of 637: Kalianget, ID.
# The weather in Kalianget is 27C with scattered clouds.
# ------------
# Retrieving record 331 of 637: Jiazi, CN.
# The weather in Jiazi is 22C with broken clouds.
# ------------
# Retrieving record 332 of 637: Salalah, OM.
# The weather in Salalah is 25C with broken clouds.
# ------------
# Retrieving record 333 of 637: Naze, JP.
# The weather in Naze is 23.66C with scattered clouds.
# ------------
# Retrieving record 334 of 637: Manokwari, ID.
# The weather in Manokwari is 27.71C with few clouds.
# ------------
# Retrieving record 335 of 637: Catamarca, AR.
# * No weather data available for this city. (Catamarca, AR) *
# ------------
# Retrieving record 336 of 637: Eresos, GR.
# The weather in Eresos is 8.33C with clear sky.
# ------------
# Retrieving record 337 of 637: Bure, ET.
# The weather in Bure is 22.96C with clear sky.
# ------------
# Retrieving record 338 of 637: Acapulco, MX.
# The weather in Acapulco is 27C with clear sky.
# ------------
# Retrieving record 339 of 637: Kjopsvik, NO.
# The weather in Kjopsvik is -3.34C with broken clouds.
# ------------
# Retrieving record 340 of 637: Lorengau, PG.
# The weather in Lorengau is 28.46C with broken clouds.
# ------------
# Retrieving record 341 of 637: Krotovka, RU.
# The weather in Krotovka is -9.55C with broken clouds.
# ------------
# Retrieving record 342 of 637: Srednekolymsk, RU.
# The weather in Srednekolymsk is -23.1C with broken clouds.
# ------------
# Retrieving record 343 of 637: Russell, NZ.
# The weather in Russell is 19C with clear sky.
# ------------
# Retrieving record 344 of 637: Bilibino, RU.
# The weather in Bilibino is -23.05C with scattered clouds.
# ------------
# Retrieving record 345 of 637: Paradwip, IN.
# * No weather data available for this city. (Paradwip, IN) *
# ------------
# Retrieving record 346 of 637: Miles City, US.
# The weather in Miles City is 1.15C with clear sky.
# ------------
# Retrieving record 347 of 637: Paita, PE.
# The weather in Paita is 24.71C with scattered clouds.
# ------------
# Retrieving record 348 of 637: Siyabuswa, ZA.
# The weather in Siyabuswa is 13.36C with clear sky.
# ------------
# Retrieving record 349 of 637: Paracatu, BR.
# The weather in Paracatu is 22.91C with scattered clouds.
# ------------
# Retrieving record 350 of 637: San Sebastian, US.
# The weather in San Sebastian is 29.16C with clear sky.
# ------------
# Retrieving record 351 of 637: Datong, CN.
# The weather in Datong is 9.11C with clear sky.
# ------------
# Retrieving record 352 of 637: Coahuayana, MX.
# The weather in Coahuayana is 19.56C with clear sky.
# ------------
# Retrieving record 353 of 637: Wattegama, LK.
# The weather in Wattegama is 24.31C with scattered clouds.
# ------------
# Retrieving record 354 of 637: Lianran, CN.
# The weather in Lianran is 17.82C with mist.
# ------------
# Retrieving record 355 of 637: Karkaralinsk, KZ.
# * No weather data available for this city. (Karkaralinsk, KZ) *
# ------------
# Retrieving record 356 of 637: Kortkeros, RU.
# The weather in Kortkeros is -8.38C with clear sky.
# ------------
# Retrieving record 357 of 637: Artyk, RU.
# * No weather data available for this city. (Artyk, RU) *
# ------------
# Retrieving record 358 of 637: Vetlanda, SE.
# The weather in Vetlanda is 1.79C with overcast clouds.
# ------------
# Retrieving record 359 of 637: Harper, LR.
# The weather in Harper is 8.96C with clear sky.
# ------------
# Retrieving record 360 of 637: Constitucion, CL.
# The weather in Constitucion is 18.98C with overcast clouds.
# ------------
# Retrieving record 361 of 637: Vao, NC.
# The weather in Vao is 1.46C with light rain.
# ------------
# Retrieving record 362 of 637: Sinnamary, GF.
# The weather in Sinnamary is 27.26C with broken clouds.
# ------------
# Retrieving record 363 of 637: South Venice, US.
# The weather in South Venice is 23.35C with overcast clouds.
# ------------
# Retrieving record 364 of 637: Tahoua, NE.
# The weather in Tahoua is 23.31C with clear sky.
# ------------
# Retrieving record 365 of 637: Usevya, TZ.
# * No weather data available for this city. (Usevya, TZ) *
# ------------
# Retrieving record 366 of 637: Kavaratti, IN.
# The weather in Kavaratti is 28.11C with clear sky.
# ------------
# Retrieving record 367 of 637: Katobu, ID.
# The weather in Katobu is 25.96C with light rain.
# ------------
# Retrieving record 368 of 637: Inirida, CO.
# The weather in Inirida is 24.46C with few clouds.
# ------------
# Retrieving record 369 of 637: Okhotsk, RU.
# The weather in Okhotsk is -7.4C with broken clouds.
# ------------
# Retrieving record 370 of 637: Samusu, WS.
# * No weather data available for this city. (Samusu, WS) *
# ------------
# Retrieving record 371 of 637: Yanam, IN.
# The weather in Yanam is 24C with mist.
# ------------
# Retrieving record 372 of 637: Hattiesburg, US.
# The weather in Hattiesburg is 13.97C with light rain.
# ------------
# Retrieving record 373 of 637: Aswan, EG.
# The weather in Aswan is 9.66C with clear sky.
# ------------
# Retrieving record 374 of 637: Faanui, PF.
# The weather in Faanui is 28.76C with few clouds.
# ------------
# Retrieving record 375 of 637: Tautira, PF.
# The weather in Tautira is 28.94C with shower rain.
# ------------
# Retrieving record 376 of 637: Puerto Quijarro, BO.
# The weather in Puerto Quijarro is 24.81C with clear sky.
# ------------
# Retrieving record 377 of 637: Bonthe, SL.
# The weather in Bonthe is 26.46C with clear sky.
# ------------
# Retrieving record 378 of 637: Komsomolskiy, RU.
# The weather in Komsomolskiy is -16.95C with scattered clouds.
# ------------
# Retrieving record 379 of 637: Labelle, CA.
# The weather in Labelle is 23.42C with overcast clouds.
# ------------
# Retrieving record 380 of 637: Arvika, SE.
# The weather in Arvika is -0.63C with scattered clouds.
# ------------
# Retrieving record 381 of 637: Alcaniz, ES.
# The weather in Alcaniz is 0.41C with clear sky.
# ------------
# Retrieving record 382 of 637: Khatanga, RU.
# The weather in Khatanga is -21.65C with scattered clouds.
# ------------
# Retrieving record 383 of 637: Murgab, TM.
# The weather in Murgab is 15C with scattered clouds.
# ------------
# Retrieving record 384 of 637: San Luis, CU.
# The weather in San Luis is 15.41C with broken clouds.
# ------------
# Retrieving record 385 of 637: Zaranj, AF.
# The weather in Zaranj is 12.71C with broken clouds.
# ------------
# Retrieving record 386 of 637: Shetpe, KZ.
# The weather in Shetpe is 4.96C with broken clouds.
# ------------
# Retrieving record 387 of 637: Fernandez, MX.
# The weather in Fernandez is 29.71C with clear sky.
# ------------
# Retrieving record 388 of 637: Permet, AL.
# The weather in Permet is -3.75C with clear sky.
# ------------
# Retrieving record 389 of 637: Moncton, CA.
# The weather in Moncton is 6.56C with light rain.
# ------------
# Retrieving record 390 of 637: Kahului, US.
# The weather in Kahului is 23.77C with scattered clouds.
# ------------
# Retrieving record 391 of 637: Pahrump, US.
# The weather in Pahrump is 12.27C with clear sky.
# ------------
# Retrieving record 392 of 637: Tombouctou, ML.
# The weather in Tombouctou is 17.26C with clear sky.
# ------------
# Retrieving record 393 of 637: Port Lincoln, AU.
# The weather in Port Lincoln is 23.16C with clear sky.
# ------------
# Retrieving record 394 of 637: Namie, JP.
# The weather in Namie is 9.1C with broken clouds.
# ------------
# Retrieving record 395 of 637: Blythe, US.
# The weather in Blythe is 19.21C with clear sky.
# ------------
# Retrieving record 396 of 637: Fort Frances, CA.
# The weather in Fort Frances is -4.11C with overcast clouds.
# ------------
# Retrieving record 397 of 637: Jabbeke, BE.
# The weather in Jabbeke is 9.76C with light rain.
# ------------
# Retrieving record 398 of 637: Ginir, ET.
# The weather in Ginir is 12.11C with clear sky.
# ------------
# Retrieving record 399 of 637: Zheleznodorozhnyy, RU.
# The weather in Zheleznodorozhnyy is -2.27C with light snow.
# ------------
# Retrieving record 400 of 637: Kotka, FI.
# The weather in Kotka is 0.7C with light rain.
# ------------
# Retrieving record 401 of 637: Kachiry, KZ.
# The weather in Kachiry is -6.5C with clear sky.
# ------------
# Retrieving record 402 of 637: Pantai Remis, MY.
# The weather in Pantai Remis is 26.58C with broken clouds.
# ------------
# Retrieving record 403 of 637: Sulangan, PH.
# The weather in Sulangan is 26.61C with clear sky.
# ------------
# Retrieving record 404 of 637: Vostok, RU.
# The weather in Vostok is -0.7C with broken clouds.
# ------------
# Retrieving record 405 of 637: Tuatapere, NZ.
# The weather in Tuatapere is 16.11C with clear sky.
# ------------
# Retrieving record 406 of 637: Mantenopolis, BR.
# The weather in Mantenopolis is 23.26C with light rain.
# ------------
# Retrieving record 407 of 637: Lisakovsk, KZ.
# The weather in Lisakovsk is -11.8C with clear sky.
# ------------
# Retrieving record 408 of 637: Izumo, JP.
# The weather in Izumo is 6C with light intensity shower rain.
# ------------
# Retrieving record 409 of 637: Saint-Augustin, CA.
# The weather in Saint-Augustin is 10.4C with overcast clouds.
# ------------
# Retrieving record 410 of 637: Alcudia, ES.
# The weather in Alcudia is 10.9C with clear sky.
# ------------
# Retrieving record 411 of 637: Sakharovo, RU.
# The weather in Sakharovo is -2.05C with overcast clouds.
# ------------
# Retrieving record 412 of 637: Santa Luzia, BR.
# The weather in Santa Luzia is 22C with light rain.
# ------------
# Retrieving record 413 of 637: Todos Santos, MX.
# The weather in Todos Santos is 19.4C with broken clouds.
# ------------
# Retrieving record 414 of 637: Conroe, US.
# The weather in Conroe is 14.16C with overcast clouds.
# ------------
# Retrieving record 415 of 637: Acoyapa, NI.
# The weather in Acoyapa is 25.31C with few clouds.
# ------------
# Retrieving record 416 of 637: Miranorte, BR.
# * No weather data available for this city. (Miranorte, BR) *
# ------------
# Retrieving record 417 of 637: Poronaysk, RU.
# The weather in Poronaysk is -0.6C with broken clouds.
# ------------
# Retrieving record 418 of 637: Husavik, IS.
# The weather in Husavik is -7.63C with clear sky.
# ------------
# Retrieving record 419 of 637: Fukue, JP.
# The weather in Fukue is 11.43C with shower rain.
# ------------
# Retrieving record 420 of 637: Gatesville, US.
# The weather in Gatesville is 10.75C with clear sky.
# ------------
# Retrieving record 421 of 637: Cookeville, US.
# The weather in Cookeville is 6.11C with broken clouds.
# ------------
# Retrieving record 422 of 637: Mehamn, NO.
# The weather in Mehamn is -1.9C with overcast clouds.
# ------------
# Retrieving record 423 of 637: Manta, EC.
# The weather in Manta is 3.89C with clear sky.
# ------------
# Retrieving record 424 of 637: Mabay, PH.
# The weather in Mabay is 24C with clear sky.
# ------------
# Retrieving record 425 of 637: Alofi, NU.
# The weather in Alofi is 26C with broken clouds.
# ------------
# Retrieving record 426 of 637: Sorland, NO.
# The weather in Sorland is 2.51C with broken clouds.
# ------------
# Retrieving record 427 of 637: Beyneu, KZ.
# The weather in Beyneu is 3.56C with broken clouds.
# ------------
# Retrieving record 428 of 637: Toamasina, MG.
# The weather in Toamasina is 23C with scattered clouds.
# ------------
# Retrieving record 429 of 637: Behshahr, IR.
# The weather in Behshahr is 4.36C with clear sky.
# ------------
# Retrieving record 430 of 637: Sistranda, NO.
# The weather in Sistranda is -0.63C with clear sky.
# ------------
# Retrieving record 431 of 637: Dondo, MZ.
# The weather in Dondo is 26.41C with light rain.
# ------------
# Retrieving record 432 of 637: San Patricio, MX.
# The weather in San Patricio is 22.71C with moderate rain.
# ------------
# Retrieving record 433 of 637: Sao Filipe, CV.
# The weather in Sao Filipe is 21.66C with clear sky.
# ------------
# Retrieving record 434 of 637: Tandil, AR.
# The weather in Tandil is 18.61C with light rain.
# ------------
# Retrieving record 435 of 637: Lamlash, GB.
# The weather in Lamlash is 4.7C with scattered clouds.
# ------------
# Retrieving record 436 of 637: Palana, RU.
# The weather in Palana is -12.45C with clear sky.
# ------------
# ...
# The weather in La Ronge is 1C with broken clouds.
# ------------
# Retrieving record 493 of 637: Wahran, DZ.
# * No weather data available for this city. (Wahran, DZ) *
# ------------
# Retrieving record 494 of 637: Parabel, RU.
# The weather in Parabel is -2.75C with few clouds.
# ------------
# Retrieving record 495 of 637: Sibolga, ID.
# The weather in Sibolga is 25.66C with clear sky.
# ------------
# Retrieving record 496 of 637: Morro Bay, US.
# The weather in Morro Bay is 17.41C with clear sky.
# ------------
# Retrieving record 497 of 637: Bemidji, US.
# The weather in Bemidji is -6.57C with clear sky.
# ------------
# Retrieving record 498 of 637: Saumur, FR.
# The weather in Saumur is 9.44C with overcast clouds.
# ------------
# Retrieving record 499 of 637: Tazovskiy, RU.
# The weather in Tazovskiy is -14.8C with scattered clouds.
# ------------
# Retrieving record 500 of 637: Ayer Itam, MY.
# * No weather data available for this city. (Ayer Itam, MY) *
# ------------
# Retrieving record 501 of 637: Bowen, AU.
# The weather in Bowen is 30.82C with clear sky.
# ------------
# Retrieving record 502 of 637: Nakhon Si Thammarat, TH.
# The weather in Nakhon Si Thammarat is 26C with few clouds.
# ------------
# Retrieving record 503 of 637: A, NO.
# * No weather data available for this city. (A, NO) *
# ------------
# Retrieving record 504 of 637: Rocha, UY.
# The weather in Rocha is 20.16C with overcast clouds.
# ------------
# Retrieving record 505 of 637: Prainha, BR.
# The weather in Prainha is 25.51C with scattered clouds.
# ------------
# Retrieving record 506 of 637: Petropavlovka, RU.
# The weather in Petropavlovka is 8.01C with clear sky.
# ------------
# Retrieving record 507 of 637: Moerai, PF.
# The weather in Moerai is 26.11C with broken clouds.
# ------------
# Retrieving record 508 of 637: Belmonte, BR.
# The weather in Belmonte is 1.67C with clear sky.
# ------------
# Retrieving record 509 of 637: Tilichiki, RU.
# The weather in Tilichiki is -15C with clear sky.
# ------------
# Retrieving record 510 of 637: Ewa Beach, US.
# The weather in Ewa Beach is 25.97C with clear sky.
# ------------
# Retrieving record 511 of 637: Makasar, ID.
# The weather in Makasar is 27.33C with few clouds.
# ------------
# Retrieving record 512 of 637: Gusau, NG.
# The weather in Gusau is 22.76C with clear sky.
# ------------
# Retrieving record 513 of 637: Abha, SA.
# The weather in Abha is 14.52C with clear sky.
# ------------
# Retrieving record 514 of 637: Palabuhanratu, ID.
# * No weather data available for this city. (Palabuhanratu, ID) *
# ------------
# Retrieving record 515 of 637: Colac, AU.
# The weather in Colac is 21.58C with clear sky.
# ------------
# Retrieving record 516 of 637: Fuerte Olimpo, PY.
# The weather in Fuerte Olimpo is 24.46C with clear sky.
# ------------
# Retrieving record 517 of 637: Upata, VE.
# The weather in Upata is 24.66C with broken clouds.
# ------------
# Retrieving record 518 of 637: Envira, BR.
# * No weather data available for this city. (Envira, BR) *
# ------------
# Retrieving record 519 of 637: Kasimov, RU.
# The weather in Kasimov is -3.55C with overcast clouds.
# ------------
# Retrieving record 520 of 637: Torata, PE.
# The weather in Torata is 4.31C with clear sky.
# ------------
# Retrieving record 521 of 637: Hasaki, JP.
# The weather in Hasaki is 10.43C with broken clouds.
# ------------
# Retrieving record 522 of 637: Louisbourg, CA.
# * No weather data available for this city. (Louisbourg, CA) *
# ------------
# Retrieving record 523 of 637: Oeiras Do Para, BR.
# The weather in Oeiras Do Para is 24.76C with light rain.
# ------------
# Retrieving record 524 of 637: Rungata, KI.
# * No weather data available for this city. (Rungata, KI) *
# ------------
# Retrieving record 525 of 637: Cabo Rojo, US.
# The weather in Cabo Rojo is 22.24C with overcast clouds.
# ------------
# Retrieving record 526 of 637: Merauke, ID.
# The weather in Merauke is 28.36C with broken clouds.
# ------------
# Retrieving record 527 of 637: Marcona, PE.
# * No weather data available for this city. (Marcona, PE) *
# ------------
# Retrieving record 528 of 637: Grand Centre, CA.
# * No weather data available for this city. (Grand Centre, CA) *
# ------------
# Retrieving record 529 of 637: Banaue, PH.
# The weather in Banaue is 19.61C with light rain.
# ------------
# Retrieving record 530 of 637: Matamoros, MX.
# The weather in Matamoros is 15C with overcast clouds.
# ------------
# Retrieving record 531 of 637: Zhuhai, CN.
# The weather in Zhuhai is 5C with clear sky.
# ------------
# Retrieving record 532 of 637: Zhezkazgan, KZ.
# The weather in Zhezkazgan is -12C with mist.
# ------------
# Retrieving record 533 of 637: Culasi, PH.
# The weather in Culasi is 27.46C with clear sky.
# ------------
# Retrieving record 534 of 637: Taltal, CL.
# The weather in Taltal is 13.36C with clear sky.
# ------------
# Retrieving record 535 of 637: Sur, OM.
# The weather in Sur is 19.96C with clear sky.
# ------------
# Retrieving record 536 of 637: Vanderhoof, CA.
# The weather in Vanderhoof is -0.75C with few clouds.
# ------------
# Retrieving record 537 of 637: Goroka, PG.
# The weather in Goroka is 17.86C with overcast clouds.
# ------------
# Retrieving record 538 of 637: Berwick, CA.
# The weather in Berwick is 13.17C with clear sky.
# ------------
# Retrieving record 539 of 637: Malwan, IN.
# * No weather data available for this city. (Malwan, IN) *
# ------------
# Retrieving record 540 of 637: Ngukurr, AU.
# * No weather data available for this city. (Ngukurr, AU) *
# ------------
# Retrieving record 541 of 637: Arivonimamo, MG.
# The weather in Arivonimamo is 18C with broken clouds.
# ------------
# Retrieving record 542 of 637: Anadyr, RU.
# The weather in Anadyr is -17.11C with light snow.
# ------------
# Retrieving record 543 of 637: Najran, SA.
# The weather in Najran is 22C with dust.
# ------------
# Retrieving record 544 of 637: Sabha, LY.
# The weather in Sabha is 5.16C with clear sky.
# ------------
# Retrieving record 545 of 637: Ilovlya, RU.
# The weather in Ilovlya is 0.7C with clear sky.
# ------------
# Retrieving record 546 of 637: Taybad, IR.
# The weather in Taybad is 11.56C with few clouds.
# ------------
# Retrieving record 547 of 637: Anchorage, US.
# The weather in Anchorage is 2.56C with scattered clouds.
# ------------
# Retrieving record 548 of 637: Evensk, RU.
# The weather in Evensk is -13.35C with scattered clouds.
# ------------
# Retrieving record 549 of 637: Noumea, NC.
# The weather in Noumea is 30C with scattered clouds.
# ------------
# Retrieving record 550 of 637: Port Moresby, PG.
# The weather in Port Moresby is 28C with broken clouds.
# ------------
# Retrieving record 551 of 637: Munteni, RO.
# The weather in Munteni is 2.41C with clear sky.
# ------------
# Retrieving record 552 of 637: Likasi, CD.
# The weather in Likasi is 18.36C with broken clouds.
# ------------
# Retrieving record 553 of 637: Camacha, PT.
# The weather in Camacha is 15C with scattered clouds.
# ------------
# Retrieving record 554 of 637: Umm Kaddadah, SD.
# The weather in Umm Kaddadah is 17.01C with clear sky.
# ------------
# Retrieving record 555 of 637: Urumqi, CN.
# * No weather data available for this city. (Urumqi, CN) *
# ------------
# Retrieving record 556 of 637: Tartagal, AR.
# The weather in Tartagal is 21.26C with moderate rain.
# ------------
# Retrieving record 557 of 637: Riberalta, BO.
# The weather in Riberalta is 24.91C with broken clouds.
# ------------
# Retrieving record 558 of 637: Mazagao, BR.
# The weather in Mazagao is 27C with broken clouds.
# ------------
# Retrieving record 559 of 637: Shenzhen, CN.
# The weather in Shenzhen is 21.41C with broken clouds.
# ------------
# Retrieving record 560 of 637: Itoman, JP.
# The weather in Itoman is 19.28C with broken clouds.
# ------------
# Retrieving record 561 of 637: Viransehir, TR.
# The weather in Viransehir is 7.01C with light rain.
# ------------
# Retrieving record 562 of 637: Fairbanks, US.
# The weather in Fairbanks is 5.11C with broken clouds.
# ------------
# Retrieving record 563 of 637: Portland, AU.
# The weather in Portland is 14.18C with broken clouds.
# ------------
# Retrieving record 564 of 637: George, ZA.
# The weather in George is 28C with few clouds.
# ------------
# Retrieving record 565 of 637: San Quintin, MX.
# The weather in San Quintin is 29.81C with clear sky.
# ------------
# Retrieving record 566 of 637: Jizan, SA.
# The weather in Jizan is 26C with clear sky.
# ------------
# Retrieving record 567 of 637: Borama, SO.
# * No weather data available for this city. (Borama, SO) *
# ------------
# Retrieving record 568 of 637: Maniitsoq, GL.
# The weather in Maniitsoq is -17.1C with scattered clouds.
# ------------
# Retrieving record 569 of 637: Mishelevka, RU.
# The weather in Mishelevka is 5.51C with clear sky.
# ------------
# Retrieving record 570 of 637: Maridi, SD.
# * No weather data available for this city. (Maridi, SD) *
# ------------
# Retrieving record 571 of 637: Geghamasar, AM.
# The weather in Geghamasar is -3.7C with scattered clouds.
# ------------
# Retrieving record 572 of 637: Vardo, NO.
# The weather in Vardo is 16.08C with thunderstorm.
# ------------
# Retrieving record 573 of 637: Astoria, US.
# The weather in Astoria is 11.29C with clear sky.
# ------------
# Retrieving record 574 of 637: Warqla, DZ.
# * No weather data available for this city. (Warqla, DZ) *
# ------------
# Retrieving record 575 of 637: Bintulu, MY.
# The weather in Bintulu is 26C with broken clouds.
# ------------
# Retrieving record 576 of 637: Maues, BR.
# The weather in Maues is 26.86C with scattered clouds.
# ------------
# Retrieving record 577 of 637: Astipalaia, GR.
# * No weather data available for this city. (Astipalaia, GR) *
# ------------
# Retrieving record 578 of 637: Atar, MR.
# The weather in Atar is 15.11C with clear sky.
# ------------
# Retrieving record 579 of 637: Mahendragarh, IN.
# The weather in Mahendragarh is 16.36C with clear sky.
# ------------
# Retrieving record 580 of 637: Motril, ES.
# The weather in Motril is 10.32C with clear sky.
# ------------
# Retrieving record 581 of 637: Santa Rosa, AR.
# The weather in Santa Rosa is 16.26C with light rain.
# ------------
# Retrieving record 582 of 637: Great Yarmouth, GB.
# The weather in Great Yarmouth is 7.98C with light rain.
# ------------
# Retrieving record 583 of 637: Miedzyrzec Podlaski, PL.
# The weather in Miedzyrzec Podlaski is 3.76C with light rain.
# ------------
# Retrieving record 584 of 637: High Level, CA.
# The weather in High Level is 6C with few clouds.
# ------------
# Retrieving record 585 of 637: Vaitupu, WF.
# * No weather data available for this city. (Vaitupu, WF) *
# ------------
# Retrieving record 586 of 637: Bandarbeyla, SO.
# The weather in Bandarbeyla is 25.06C with overcast clouds.
# ------------
# Retrieving record 587 of 637: Custoias, PT.
# The weather in Custoias is -0.4C with few clouds.
# ------------
# Retrieving record 588 of 637: Obihiro, JP.
# The weather in Obihiro is -1C with light shower snow.
# ------------
# Retrieving record 589 of 637: Coari, BR.
# The weather in Coari is 26.01C with clear sky.
# ------------
# Retrieving record 590 of 637: Kerema, PG.
# The weather in Kerema is 24.31C with light rain.
# ------------
# Retrieving record 591 of 637: Matara, LK.
# The weather in Matara is 8.86C with scattered clouds.
# ------------
# Retrieving record 592 of 637: Kuytun, CN.
# The weather in Kuytun is 3.01C with clear sky.
# ------------
# Retrieving record 593 of 637: Sorvag, FO.
# * No weather data available for this city. (Sorvag, FO) *
# ------------
# Retrieving record 594 of 637: Port Blair, IN.
# The weather in Port Blair is 28.46C with clear sky.
# ------------
# Retrieving record 595 of 637: Vacha, RU.
# The weather in Vacha is -4.7C with overcast clouds.
# ------------
# Retrieving record 596 of 637: Branford, US.
# The weather in Branford is 11.43C with moderate rain.
# ------------
# Retrieving record 597 of 637: Aljezur, PT.
# The weather in Aljezur is 12.61C with clear sky.
# ------------
# Retrieving record 598 of 637: Hualmay, PE.
# The weather in Hualmay is 20.16C with few clouds.
# ------------
# Retrieving record 599 of 637: Mazabuka, ZM.
# The weather in Mazabuka is 21.06C with few clouds.
# ------------
# Retrieving record 600 of 637: Itarema, BR.
# The weather in Itarema is 23.91C with broken clouds.
# ------------
# Retrieving record 601 of 637: Erzin, RU.
# The weather in Erzin is 10.74C with light intensity shower rain.
# ------------
# Retrieving record 602 of 637: Bolungarvik, IS.
# * No weather data available for this city. (Bolungarvik, IS) *
# ------------
# Retrieving record 603 of 637: Bahir Dar, ET.
# The weather in Bahir Dar is 12.76C with clear sky.
# ------------
# Retrieving record 604 of 637: Galgani, SD.
# * No weather data available for this city. (Galgani, SD) *
# ------------
# Retrieving record 605 of 637: Kushima, JP.
# The weather in Kushima is 10.63C with few clouds.
# ------------
# Retrieving record 606 of 637: Surgut, RU.
# The weather in Surgut is -4C with light shower snow.
# ------------
# Retrieving record 607 of 637: Mehriz, IR.
# The weather in Mehriz is 8C with clear sky.
# ------------
# Retrieving record 608 of 637: Lowicz, PL.
# The weather in Lowicz is 4.89C with light intensity shower rain.
# ------------
# Retrieving record 609 of 637: Eirunepe, BR.
# The weather in Eirunepe is 24.36C with light rain.
# ------------
# Retrieving record 610 of 637: Abay, KZ.
# The weather in Abay is -7C with overcast clouds.
# ------------
# Retrieving record 611 of 637: Kipini, KE.
# The weather in Kipini is 27.21C with scattered clouds.
# ------------
# Retrieving record 612 of 637: Sysert, RU.
# The weather in Sysert is -9C with clear sky.
# ------------
# Retrieving record 613 of 637: Sobolevo, RU.
# The weather in Sobolevo is -0.3C with overcast clouds.
# ------------
# Retrieving record 614 of 637: Kattivakkam, IN.
# The weather in Kattivakkam is 25.1C with mist.
# ------------
# Retrieving record 615 of 637: Sola, VU.
# The weather in Sola is 4.44C with light rain.
# ------------
# Retrieving record 616 of 637: Mezen, RU.
# The weather in Mezen is -2.55C with overcast clouds.
# ------------
# Retrieving record 617 of 637: Lazaro Cardenas, MX.
# The weather in Lazaro Cardenas is 15.17C with clear sky.
# ------------
# Retrieving record 618 of 637: Amazar, RU.
# The weather in Amazar is 0.16C with clear sky.
# ------------
# Retrieving record 619 of 637: Dunedin, NZ.
# The weather in Dunedin is 18.33C with few clouds.
# ------------
# Retrieving record 620 of 637: Turtkul, UZ.
# * No weather data available for this city. (Turtkul, UZ) *
# ------------
# Retrieving record 621 of 637: Aden, YE.
# The weather in Aden is 25.66C with overcast clouds.
# ------------
# Retrieving record 622 of 637: Utiel, ES.
# The weather in Utiel is 9.69C with clear sky.
# ------------
# Retrieving record 623 of 637: Saint-Andre-Avellin, CA.
# The weather in Saint-Andre-Avellin is 3.48C with light intensity shower rain.
# ------------
# Retrieving record 624 of 637: Bairiki, KI.
# * No weather data available for this city. (Bairiki, KI) *
# ------------
# Retrieving record 625 of 637: Laguna, BR.
# The weather in Laguna is 21C with clear sky.
# ------------
# Retrieving record 626 of 637: Ilinskiy, RU.
# The weather in Ilinskiy is -2.26C with light snow.
# ------------
# Retrieving record 627 of 637: Viedma, AR.
# The weather in Viedma is 17.41C with moderate rain.
# ------------
# Retrieving record 628 of 637: Kizukuri, JP.
# The weather in Kizukuri is 4.52C with broken clouds.
# ------------
# Retrieving record 629 of 637: Vilyuysk, RU.
# The weather in Vilyuysk is -12C with scattered clouds.
# ------------
# Retrieving record 630 of 637: Mikhaylovka, KZ.
# The weather in Mikhaylovka is 5.51C with clear sky.
# ------------
# Retrieving record 631 of 637: Alice Springs, AU.
# The weather in Alice Springs is 32C with few clouds.
# ------------
# Retrieving record 632 of 637: Ahuimanu, US.
# The weather in Ahuimanu is 25.97C with few clouds.
# ------------
# Retrieving record 633 of 637: Galveston, US.
# The weather in Galveston is 0.91C with clear sky.
# ------------
# Retrieving record 634 of 637: Solnechnyy, RU.
# The weather in Solnechnyy is 0.01C with clear sky.
# ------------
# Retrieving record 635 of 637: Cap Malheureux, MU.
# The weather in Cap Malheureux is 23.07C with few clouds.
# ------------
# Retrieving record 636 of 637: Formoso Do Araguaia, BR.
# * No weather data available for this city. (Formoso Do Araguaia, BR) *
# ------------
# Retrieving record 637 of 637: Nishihara, JP.
# The weather in Nishihara is 11.41C with broken clouds.
# ------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.to_csv("weather_data.csv", index=False)

# %%
weather_df=weather_df[weather_df["Latitude"] != '']
weather_df.head()
# Out:
#           City Country Latitude Longitude    DateTime CurrentTemp MaxTemp  \
# 0      Mataura      NZ   -46.19    168.86  1552699807       15.56   15.56
# 1    Cape Town      ZA   -33.93     18.42  1552699690       19.39   21.11
# 2  Maine-Soroa      NE    13.21     12.02  1552700284       23.91   23.91
# 3       Castro      CL   -42.48    -73.76  1552698000          12      12
# 4  Ostrogozhsk      RU    50.86     39.08  1552700287        0.16    0.16
#
#   WindSpeed Cloudiness Humidity
# 0      6.71          0       73
# 1       2.6          0       82
# 2      5.32         32       23
# 3       2.1          0       81
# 4      4.02         92       95

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["MaxTemp"],color='m', edgecolor='k',
            linewidth= 1, marker='o', alpha=0.6)


plt.title("Comparison of Daily High Temperature across Latitudes")
plt.ylabel("Temperature C")
plt.xlabel("Latitude of City coordinates")
plt.grid(b=True, which='major', color='lightgray', linestyle='-')

plt.savefig("TEMPvLAT.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Humidity"],color='aqua', edgecolor='k',
            linewidth= 1, marker='o', alpha=0.6)

plt.title("Comparison of Humiditude across Latitudes")
plt.ylabel("% Humidity")
plt.xlabel("Latitude of City coordinates")
plt.grid(b=True, which='major', color='lightgray', linestyle='-')

plt.savefig("HUMvLAT.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Cloudiness"],color='gray', edgecolor='k',
            linewidth= 1, marker='o', alpha=0.6)

plt.title("Comparison of Cloudiness across Latitudes")
plt.ylabel("% Cloud Coverage")
plt.xlabel("Latitude of City coordinates")
plt.grid(b=True, which='major', color='lightgray', linestyle='-')

plt.savefig("CLOUDSvLAT.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["WindSpeed"],color='yellow', edgecolor='k',
            linewidth= 1, marker='o', alpha=0.7)

plt.title("Comparison of wind speed across Latitudes")
plt.ylabel("Wind speed (mph)")
plt.xlabel("Latitude of City coordinates")
plt.grid(b=True, which='major', color='lightgray', linestyle='-')

plt.savefig("WINDvLAT.png")
